# %% [markdown]
# # <font color="#F5AD27">__PI - Instacart Market Basket Analysis__</font>
# ## <font color="#F5AD27">__EDA__</font>
#
#
# ---

# %% [markdown]
# ### <font color="#F5AD27">__Importación de librerías__</font>
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from cargar_datos import load_all

# %% [markdown]
# ### <font color="#F5AD27">__Carga de datos__</font>

# %%
dfs = load_all()
# Out:
# ...
# Cargando datasets — Instacart Market Basket Analysis
# ...
# ✔ aisles                                134 filas  |  2 cols  |  0.0 MB  |  0.0s
# ✔ departments                            21 filas  |  2 cols  |  0.0 MB  |  0.0s
# ✔ products                           49,688 filas  |  4 cols  |  4.1 MB  |  0.0s
# ✔ orders                          3,421,083 filas  |  7 cols  |  55.5 MB  |  1.5s
# ✔ order_products__prior          32,434,489 filas  |  4 cols  |  340.3 MB  |  8.4s
# ✔ order_products__train           1,384,617 filas  |  4 cols  |  14.5 MB  |  0.4s
# ...
# Total en memoria: 414.3 MB
# ...

# %%
df_orders               = dfs["orders"]
df_products             = dfs["products"]
df_aisles               = dfs["aisles"]
df_departments          = dfs["departments"]
df_order_products_prior = dfs["order_products_prior"]
df_order_products_train = dfs["order_products_train"]

# %% [markdown]
# ### <font color="#F5AD27">__Exploración del dataset__</font>
# ---

# %%
# orders ────────────────────────────────────────────────────────────────────
print('Orders:')
print('--------------------------------------------------------------------')
# Cantidad de registros y atributos de la selección
print(f'🔍La cantidad de registros del dataset es de: {df_orders.shape[0]}.')
print(f'🔍La cantidad de atributos del dataset es de: {df_orders.shape[1]}.')
print('--------------------------------------------------------------------')

# Identificando si hay valores nulos
print("Cantidad de nulos: ")
print(f"{df_orders.isnull().sum()}")
print('--------------------------------------------------------------------')

# Identificando si hay valores duplicados
duplicados = df_orders.duplicated().any()
if duplicados:
    print("Hay registros duplicados en el DataFrame.")
else:
    print("No hay registros duplicados en el DataFrame.")
print('--------------------------------------------------------------------')

# Tipos de datos
print(f'Tipos de datos: {df_orders.dtypes.to_frame("dtype")}')
print('--------------------------------------------------------------------')

# Breve panorama del dataset
print('Breve panorama del dataset:')
df_orders.head()
# Out:
# Orders:
# --------------------------------------------------------------------
# 🔍La cantidad de registros del dataset es de: 3421083.
# 🔍La cantidad de atributos del dataset es de: 7.
# --------------------------------------------------------------------
# Cantidad de nulos:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64
# --------------------------------------------------------------------
# No hay registros duplicados en el DataFrame.
# --------------------------------------------------------------------
# Tipos de datos:                            dtype
# order_id                   int32
# user_id                    int32
# eval_set                category
# order_number               int16
# order_dow                   int8
# order_hour_of_day           int8
# ...

# %%
#  products  ────────────────────────────────────────────────────────────────────
print('Products :')
print('--------------------------------------------------------------------')
# Cantidad de registros y atributos de la selección
print(f'🔍La cantidad de registros del dataset es de: {df_products.shape[0]}.')
print(f'🔍La cantidad de atributos del dataset es de: {df_products.shape[1]}.')
print('--------------------------------------------------------------------')

# Identificando si hay valores nulos
print("Cantidad de nulos: ")
print(f"{df_products.isnull().sum()}")
print('--------------------------------------------------------------------')

# Identificando si hay valores duplicados
duplicados = df_products.duplicated().any()
if duplicados:
    print("Hay registros duplicados en el DataFrame.")
else:
    print("No hay registros duplicados en el DataFrame.")
print('--------------------------------------------------------------------')

# Tipos de datos
print(f'Tipos de datos: {df_products.dtypes.to_frame("dtype")}')
print('--------------------------------------------------------------------')

# Breve panorama del dataset
print('Breve panorama del dataset:')
df_products.head()
# Out:
# Products :
# --------------------------------------------------------------------
# 🔍La cantidad de registros del dataset es de: 49688.
# 🔍La cantidad de atributos del dataset es de: 4.
# --------------------------------------------------------------------
# Cantidad de nulos:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64
# --------------------------------------------------------------------
# No hay registros duplicados en el DataFrame.
# --------------------------------------------------------------------
# Tipos de datos:                 dtype
# product_id      int32
# product_name   object
# aisle_id         int8
# department_id    int8
# --------------------------------------------------------------------
# Breve panorama del dataset:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# ...

# %%
#  aisles  ────────────────────────────────────────────────────────────────────
print('Aisles :')
print('--------------------------------------------------------------------')
# Cantidad de registros y atributos de la selección
print(f'🔍La cantidad de registros del dataset es de: {df_aisles.shape[0]}.')
print(f'🔍La cantidad de atributos del dataset es de: {df_aisles.shape[1]}.')
print('--------------------------------------------------------------------')

# Identificando si hay valores nulos
print("Cantidad de nulos: ")
print(f"{df_aisles.isnull().sum()}")
print('--------------------------------------------------------------------')

# Identificando si hay valores duplicados
duplicados = df_aisles.duplicated().any()
if duplicados:
    print("Hay registros duplicados en el DataFrame.")
else:
    print("No hay registros duplicados en el DataFrame.")
print('--------------------------------------------------------------------')

# Tipos de datos
print(f'Tipos de datos: {df_aisles.dtypes.to_frame("dtype")}')
print('--------------------------------------------------------------------')

# Breve panorama del dataset
print('Breve panorama del dataset:')
df_aisles.head()
# Out:
# Aisles :
# --------------------------------------------------------------------
# 🔍La cantidad de registros del dataset es de: 134.
# 🔍La cantidad de atributos del dataset es de: 2.
# --------------------------------------------------------------------
# Cantidad de nulos:
# aisle_id    0
# aisle       0
# dtype: int64
# --------------------------------------------------------------------
# No hay registros duplicados en el DataFrame.
# --------------------------------------------------------------------
# Tipos de datos:              dtype
# aisle_id      int8
# aisle     category
# --------------------------------------------------------------------
# Breve panorama del dataset:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
# Departments  ────────────────────────────────────────────────────────────────────
print('Departments:')
print('--------------------------------------------------------------------')
# Cantidad de registros y atributos de la selección
print(f'🔍La cantidad de registros del dataset es de: {df_departments.shape[0]}.')
print(f'🔍La cantidad de atributos del dataset es de: {df_departments.shape[1]}.')
print('--------------------------------------------------------------------')

# Identificando si hay valores nulos
print("Cantidad de nulos: ")
print(f"{df_departments.isnull().sum()}")
print('--------------------------------------------------------------------')

# Identificando si hay valores duplicados
duplicados = df_departments.duplicated().any()
if duplicados:
    print("Hay registros duplicados en el DataFrame.")
else:
    print("No hay registros duplicados en el DataFrame.")
print('--------------------------------------------------------------------')

# Tipos de datos
print(f'Tipos de datos: {df_departments.dtypes.to_frame("dtype")}')
print('--------------------------------------------------------------------')

# Breve panorama del dataset
print('Breve panorama del dataset:')
df_departments.head()
# Out:
# Departments:
# --------------------------------------------------------------------
# 🔍La cantidad de registros del dataset es de: 21.
# 🔍La cantidad de atributos del dataset es de: 2.
# --------------------------------------------------------------------
# Cantidad de nulos:
# department_id    0
# department       0
# dtype: int64
# --------------------------------------------------------------------
# No hay registros duplicados en el DataFrame.
# --------------------------------------------------------------------
# Tipos de datos:                   dtype
# department_id      int8
# department     category
# --------------------------------------------------------------------
# Breve panorama del dataset:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# order_products_prior  ────────────────────────────────────────────────────────────────────
print('order_products_prior :')
print('--------------------------------------------------------------------')
# Cantidad de registros y atributos de la selección
print(f'🔍La cantidad de registros del dataset es de: {df_order_products_prior.shape[0]}.')
print(f'🔍La cantidad de atributos del dataset es de: {df_order_products_prior.shape[1]}.')
print('--------------------------------------------------------------------')

# Identificando si hay valores nulos
print("Cantidad de nulos: ")
print(f"{df_order_products_prior.isnull().sum()}")
print('--------------------------------------------------------------------')

# Identificando si hay valores duplicados
duplicados = df_order_products_prior.duplicated().any()
if duplicados:
    print("Hay registros duplicados en el DataFrame.")
else:
    print("No hay registros duplicados en el DataFrame.")
print('--------------------------------------------------------------------')

# Tipos de datos
print(f'Tipos de datos: {df_order_products_prior.dtypes.to_frame("dtype")}')
print('--------------------------------------------------------------------')

# Breve panorama del dataset
print('Breve panorama del dataset:')
df_order_products_prior.head()
# Out:
# order_products_prior :
# --------------------------------------------------------------------
# 🔍La cantidad de registros del dataset es de: 32434489.
# 🔍La cantidad de atributos del dataset es de: 4.
# --------------------------------------------------------------------
# Cantidad de nulos:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64
# --------------------------------------------------------------------
# No hay registros duplicados en el DataFrame.
# --------------------------------------------------------------------
# Tipos de datos:                    dtype
# order_id           int32
# product_id         int32
# add_to_cart_order  int16
# reordered           int8
# --------------------------------------------------------------------
# Breve panorama del dataset:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# ...

# %%
# order_products_train  ────────────────────────────────────────────────────────────────────
print('order_products_train :')
print('--------------------------------------------------------------------')
# Cantidad de registros y atributos de la selección
print(f'🔍La cantidad de registros del dataset es de: {df_order_products_train.shape[0]}.')
print(f'🔍La cantidad de atributos del dataset es de: {df_order_products_train.shape[1]}.')
print('--------------------------------------------------------------------')

# Identificando si hay valores nulos
print("Cantidad de nulos: ")
print(f"{df_order_products_train.isnull().sum()}")
print('--------------------------------------------------------------------')

# Identificando si hay valores duplicados
duplicados = df_order_products_train.duplicated().any()
if duplicados:
    print("Hay registros duplicados en el DataFrame.")
else:
    print("No hay registros duplicados en el DataFrame.")
print('--------------------------------------------------------------------')

# Tipos de datos
print(f'Tipos de datos: {df_order_products_train.dtypes.to_frame("dtype")}')
print('--------------------------------------------------------------------')

# Breve panorama del dataset
print('Breve panorama del dataset:')
df_order_products_train

df_order_products_train.head()
# Out:
# order_products_train :
# --------------------------------------------------------------------
# 🔍La cantidad de registros del dataset es de: 1384617.
# 🔍La cantidad de atributos del dataset es de: 4.
# --------------------------------------------------------------------
# Cantidad de nulos:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64
# --------------------------------------------------------------------
# No hay registros duplicados en el DataFrame.
# --------------------------------------------------------------------
# Tipos de datos:                    dtype
# order_id           int32
# product_id         int32
# add_to_cart_order  int16
# reordered           int8
# --------------------------------------------------------------------
# Breve panorama del dataset:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# ...
